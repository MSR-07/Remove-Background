# %%
# !pip install rembg
# Out:
# ...
#      ---------------------------------------- 56.9/56.9 kB 1.0 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 55.5/55.5 kB 2.8 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 56.3/56.3 kB 2.9 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 14.6/14.6 MB 1.6 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 2.5/2.5 MB 1.7 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 40.1/40.1 MB 2.0 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 78.4/78.4 kB 2.2 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 35.5/35.5 MB 2.1 MB/s eta 0:00:00
# ...
#      -------------------------------------- 319.7/319.7 kB 2.0 MB/s eta 0:00:00
# ...
#      -------------------------------------- 296.5/296.5 kB 2.0 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...

# %%
from rembg import remove
from PIL import Image
# Out:
# C:\Users\Saif\AppData\Local\Programs\Python\Python310\lib\site-packages\paramiko\transport.py:236: CryptographyDeprecationWarning: Blowfish has been deprecated
#   "class": algorithms.Blowfish,

# %%
input_path = '.\Assets\Pic\One.jpeg'
output_path = '.\Assets\Pic\Output.png'

# %%
input = Image.open(input_path)
output = remove(input)
output.save(output_path)
# Out:
# ...
# 100%|#######################################| 176M/176M [00:00<00:00, 35.5GB/s]
